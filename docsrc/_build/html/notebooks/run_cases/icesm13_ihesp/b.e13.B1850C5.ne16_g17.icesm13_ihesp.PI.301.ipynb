# %%
import os
import shutil

# !hostname
# Out:
# cheyenne6

# %%
os.environ['PROJECT'] = 'P93300324'

casename = 'b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301'
cesm_dir = '/glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu'
case_dir = f'/glade/u/home/fengzhu/CESM/cases/{casename}'
output_root = f'/glade/scratch/fengzhu/CESM_output'
output_dir = os.path.join(output_root, casename)

print('case_dir', case_dir)
print('output_dir', output_dir)

shutil.rmtree(case_dir) if os.path.exists(case_dir) else None
shutil.rmtree(output_dir) if os.path.exists(output_dir) else None
# Out:
# case_dir /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301
# output_dir /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301

# %%
# !$cesm_dir/cime/scripts/create_newcase --case $case_dir --res ne16_g17 --machine cheyenne --compset 1850_CAM50_CLM40%SP_CICE_POP2_RTM_SGLC_SWAV --output-root $output_root --run-unsupported || exit 1
# Out:
# Compset longname is 1850_CAM50_CLM40%SP_CICE_POP2_RTM_SGLC_SWAV
# Compset specification file is /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime_config/config_compsets.xml
# Warning: missing non-idmap ROF2OCN_RMAPNAME for ocn_grid, gx1v7 and rof_grid r05
# Compset forcing is 1850
# ATM component is CAM cam5 physics:
# LND component is clm4.0:Satellite phenology:
# ICE component is Sea ICE (cice) model version 4
# OCN component is POP2
# ROF component is RTM: River Transport Model
# GLC component is Stub glacier (land ice) component
# WAV component is Stub wave component
# ESP component is
# Pes     specification file is /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime_config/config_pes.xml
# Compset specific settings: name is RUN_STARTDATE and value is 0001-01-01
# Machine is cheyenne
# Pes setting: grid          is a%ne16np4_l%ne16np4_oi%gx1v7_r%r05_g%null_w%null_m%gx1v7
# Pes setting: compset       is 1850_CAM50_CLM40%SP_CICE_POP2_RTM_SGLC_SWAV
# Pes setting: tasks       is {'NTASKS_ATM': -3, 'NTASKS_LND': -1, 'NTASKS_ROF': -1, 'NTASKS_ICE': -2, 'NTASKS_OCN': -1, 'NTASKS_GLC': -1, 'NTASKS_WAV': -1, 'NTASKS_CPL': -3}
# Pes setting: threads     is {'NTHRDS_ATM': 1, 'NTHRDS_LND': 1, 'NTHRDS_ROF': 1, 'NTHRDS_ICE': 1, 'NTHRDS_OCN': 1, 'NTHRDS_GLC': 1, 'NTHRDS_WAV': 1, 'NTHRDS_CPL': 1}
# Pes setting: rootpe      is {'ROOTPE_ATM': 0, 'ROOTPE_LND': 0, 'ROOTPE_ROF': 0, 'ROOTPE_ICE': -1, 'ROOTPE_OCN': -3, 'ROOTPE_GLC': 0, 'ROOTPE_WAV': 0, 'ROOTPE_CPL': 0}
# Pes setting: pstrid      is {}
# Pes other settings: {}
# Pes comments: none
#  Compset is: 1850_CAM50_CLM40%SP_CICE_POP2_RTM_SGLC_SWAV
#  Grid is: a%ne16np4_l%ne16np4_oi%gx1v7_r%r05_g%null_w%null_m%gx1v7
#  Components in compset are: ['cam', 'clm', 'cice', 'pop', 'rtm', 'sglc', 'swav', 'sesp', 'drv', 'dart']
# Using project from env PROJECT: P93300324
# No charge_account info available, using value from PROJECT
# WARNING: No cesm Model version found.
# Batch_system_type is pbs
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE None
# job is case.st_archive USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE None
#  Creating Case directory /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_case.xml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles

# %%
# !cp /glade/p/cesm/palwg/paleoweather/cesm_tags/mods/cam_diagnostics.F90   $case_dir/SourceMods/src.cam/
# !cp $cesm_dir/components/clm/src_clm40/biogeophys/BalanceCheckMod.F90   $case_dir/SourceMods/src.clm/
# !sed -i '817 s/^/\!/' $case_dir/SourceMods/src.clm/BalanceCheckMod.F90
# !sed -i '818 s/^/\!/' $case_dir/SourceMods/src.clm/BalanceCheckMod.F90

# %%
os.chdir(case_dir)
os.getcwd()
# Out:
# '/glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301'

# %%
# !./xmlchange RUN_TYPE=startup,GET_REFCASE=FALSE
# !./xmlchange CAM_CONFIG_OPTS="-water_tracer h2o_h216o_hdo_h218o" --append
# !./xmlchange OCN_TRACER_MODULES="iage wiso"
# !./xmlchange FLDS_WISO=TRUE
# !./xmlchange CLM_FORCE_COLDSTART=on
# !./xmlchange CLM_BLDNML_OPTS="-ignore_warnings" --append
# !./xmlchange OCN_NCPL=1,CPL_SEQ_OPTION=CESM1_MOD  # daily coupling

ntasks_atm = 1536
ntasks_ocn = 256
ntasks_lnd = 512
ntasks_ice = 1024
# !./xmlchange NTASKS_CPL=$ntasks_atm,NTHRDS_CPL=1,ROOTPE_CPL=0
# !./xmlchange NTASKS_ATM=$ntasks_atm,NTHRDS_ATM=1,ROOTPE_ATM=0
# !./xmlchange NTASKS_LND=$ntasks_lnd,NTHRDS_LND=1,ROOTPE_LND=0
# !./xmlchange NTASKS_ICE=$ntasks_ice,NTHRDS_ICE=1,ROOTPE_ICE=$ntasks_lnd
# !./xmlchange NTASKS_OCN=$ntasks_ocn,NTHRDS_OCN=1,ROOTPE_OCN=$ntasks_atm
# !./xmlchange NTASKS_ROF=$ntasks_lnd,NTHRDS_ROF=1,ROOTPE_ROF=0

# %%
gridmap_dir = '/glade/p/cesmdata/inputdata/cpl/gridmaps/'
# !./xmlchange ATM2OCN_FMAPNAME=$gridmap_dir/ne16np4/map_ne16np4_TO_gx1v7_aave.171018.nc
# !./xmlchange ATM2OCN_SMAPNAME=$gridmap_dir/ne16np4/map_ne16np4_TO_gx1v7_blin.171018.nc
# !./xmlchange ATM2OCN_VMAPNAME=$gridmap_dir/ne16np4/map_ne16np4_TO_gx1v7_patc.171018.nc
# !./xmlchange OCN2ATM_FMAPNAME=$gridmap_dir/gx1v7/map_gx1v7_TO_ne16np4_aave.171018.nc
# !./xmlchange OCN2ATM_SMAPNAME=$gridmap_dir/gx1v7/map_gx1v7_TO_ne16np4_aave.171018.nc
# !./xmlchange LND2ROF_FMAPNAME=$gridmap_dir/
# !./xmlchange ROF2LND_FMAPNAME=$gridmap_dir/
# !./xmlchange ROF2OCN_FMAPNAME=$gridmap_dir/
# !./xmlchange ROF2OCN_RMAPNAME=$gridmap_dir/r05/map_r05_to_gx1v7_nnsm_e1000r300_170413.nc

# %%
# !./case.setup
# Out:
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/config/cesm/machines/Depends.intel -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301
# /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_mach_specific.xml already exists, delete to replace
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE None
# Creating batch scripts
# Writing case.run script from input template /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_mach_pes.xml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_batch.xml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles
# Creating user_nl_xxx files for components and cpl
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/drivers/mct/cime_config/user_nl_cpl -> .
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cam//cime_config/user_nl_cam ->
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/clm//cime_config/user_nl_clm ->
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cice//cime_config/user_nl_cice ->
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/pop//cime_config/user_nl_pop ->
# copying /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/rtm//cime_config/user_nl_rtm ->
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run

# %%
with open('./user_nl_cam', 'a') as f:
    f.write('''
        cldfrc_rhminl  = 0.8800D0
        micro_mg_dcs   = 400.D-6
        dust_emis_fact = 0.95D0
        wtrc_limiter_phis_crit = 100000.0
    ''')

# %%
with open('./user_nl_pop', 'a') as f:
    f.write('''
        ! namelists for wiso
        wiso_use_nml_surf_vals      = .false.
        wiso_comp_surf_avg_freq_opt = 'nmonth'
        wiso_comp_surf_avg_freq     = 1
        init_ts_suboption       = 'spunup'
        init_ts_file_fmt        = 'nc'
        init_ts_file            = '/glade/p/cgd/ppc/jiangzhu/rest/b.e13.Bi1850C5.f19_g16.05/b.e13.Bi1850C5.f19_g16.05.pop.r.0505-01-01-00000.nc'
    ''')

# %%
with open('./user_nl_cice', 'a') as f:
    f.write('''
        ice_ic = '/glade/p/cgd/ppc/jiangzhu/rest/b.e13.Bi1850C5.f19_g16.05/b.e13.Bi1850C5.f19_g16.05.cice.r.0505-01-01-00000.nc'
    ''')

# %%
with open('./user_nl_rtm', 'a') as f:
    f.write('''
        finidat_rtm = '/glade/p/cgd/ppc/jiangzhu/rest/b.e13.Bi1850C5.f19_g16.05/b.e13.Bi1850C5.f19_g16.05.rtm.r.0505-01-01-00000.nc'
        wiso_runoff= .true.
    ''')

# %%
# !./preview_namelists
# Out:
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Creating component namelists
#   2023-04-25 15:19:23 atm
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cam//cime_config/buildnml
#      ...calling cam buildcpp to set build time options
# CAM namelist copy: file1 /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/atm_in file2 /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_in
#   2023-04-25 15:19:24 lnd
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/clm//cime_config/buildnml
#      ...calling clm buildcpp to set build time options
# WARNING: CLM is starting up from a cold state
#   2023-04-25 15:19:25 ice
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-04-25 15:19:25 ocn
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#      POP build-namelist: ocn_grid is gx1v7
# POP build-namelist: ocn_tracer_modules are iage wiso
#   2023-04-25 15:19:50 rof
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/rtm//cime_config/buildnml
#   2023-04-25 15:19:50 glc
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/sglc/cime_config/buildnml
#   2023-04-25 15:19:50 wav
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/swav/cime_config/buildnml
#   2023-04-25 15:19:50 esp
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/sesp/cime_config/buildnml
#   2023-04-25 15:19:50 cpl
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/drivers/mct/cime_config/buildnml
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/drv_in -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs/drv_flds_in -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/seq_maps.rc -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/glc_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/ocn_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/esp_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/ice_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/wav_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/lnd_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/atm_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/rof_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/cpl_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# Finished creating component namelists
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/glc_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ocn_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/esp_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ice_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/wav_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/lnd_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/rof_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/cpl_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ice_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/rof_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/drv_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/pop_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/drv_flds_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/lnd_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/seq_maps.rc -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/chem_mech.in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/chem_mech.doc -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs

# %%
# !qcmd -A $PROJECT -- ./case.build || exit 3
# Out:
# Submitting command to PBS using account P93300324:
#     ./case.build
#
# Requested custom PBS options:
#     -A P93300324
#
# Waiting for job 9784085.chadmin1.ib0.cheyenne.ucar.edu to start ...
#
#
# Building case in directory /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301
# sharedlib_only is False
# model_only is False
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# Creating component namelists
#   2023-04-25 15:20:15 atm
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cam//cime_config/buildnml
#      ...calling cam buildcpp to set build time options
# CAM namelist copy: file1 /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/atm_in file2 /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_in
#   2023-04-25 15:20:16 lnd
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/clm//cime_config/buildnml
#      ...calling clm buildcpp to set build time options
# WARNING: CLM is starting up from a cold state
#   2023-04-25 15:20:16 ice
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-04-25 15:20:17 ocn
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#      POP build-namelist: ocn_grid is gx1v7
# POP build-namelist: ocn_tracer_modules are iage wiso
#   2023-04-25 15:20:41 rof
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/rtm//cime_config/buildnml
#   2023-04-25 15:20:41 glc
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/sglc/cime_config/buildnml
#   2023-04-25 15:20:41 wav
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/swav/cime_config/buildnml
#   2023-04-25 15:20:41 esp
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/sesp/cime_config/buildnml
#   2023-04-25 15:20:41 cpl
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/drivers/mct/cime_config/buildnml
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/drv_in -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs/drv_flds_in -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/seq_maps.rc -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/glc_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/ocn_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/esp_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/ice_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/wav_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/lnd_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/atm_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/rof_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/cpl_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# Finished creating component namelists
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/glc_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ocn_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/esp_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ice_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/wav_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/lnd_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/rof_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/cpl_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ice_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/rof_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/drv_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/pop_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/drv_flds_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/lnd_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/seq_maps.rc -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/chem_mech.in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/chem_mech.doc -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# Building gptl with output to file /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/gptl.bldlog.230425-152015
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/build_scripts/buildlib.gptl
# Building mct with output to file /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/mct.bldlog.230425-152015
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/build_scripts/buildlib.mct
# Building pio with output to file /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/pio.bldlog.230425-152015
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/build_scripts/buildlib.pio
# Component pio build complete with 2 warnings
# Building csm_share with output to file /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/csm_share.bldlog.230425-152015
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/build_scripts/buildlib.csm_share
# Component csm_share build complete with 20 warnings
#          - Building clm library
# Building lnd with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lnd.bldlog.230425-152015
# Component lnd build complete with 1 warnings
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/intel/mpt/nodebug/nothreads/mct/mct/noesmf/clm/obj/lnd_comp_esmf.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/intel/mpt/nodebug/nothreads/mct/mct/noesmf/include
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/intel/mpt/nodebug/nothreads/mct/mct/noesmf/clm/obj/lnd_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/intel/mpt/nodebug/nothreads/mct/mct/noesmf/include
# clm built in 107.074559 seconds
#          - Building atm Library
# Building atm with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/atm.bldlog.230425-152015
#          - Building ice Library
# Building ice with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/ice.bldlog.230425-152015
#          - Building ocn Library
# Building ocn with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/ocn.bldlog.230425-152015
#          - Building rof Library
# Building rof with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/rof.bldlog.230425-152015
#          - Building glc Library
# Building glc with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/glc.bldlog.230425-152015
#          - Building wav Library
# Building wav with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/wav.bldlog.230425-152015
#          - Building esp Library
# Building esp with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/esp.bldlog.230425-152015
# sesp built in 1.510170 seconds
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/glc/obj/glc_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# sglc built in 2.031809 seconds
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/wav/obj/wav_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# swav built in 4.590219 seconds
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/rof/obj/rof_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/rof/obj/rof_comp_esmf.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# rtm built in 20.135028 seconds
# Component ice build complete with 1 warnings
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/ice/obj/ice_comp_esmf.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/ice/obj/ice_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# cice built in 80.409408 seconds
# Component ocn build complete with 6 warnings
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/ocn/obj/ocn_comp_esmf.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/ocn/obj/ocn_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# pop built in 114.053320 seconds
# Component atm build complete with 11 warnings
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/atm/obj/atm_comp_esmf.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/atm/obj/atm_comp_mct.mod -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/lib/include
# cam built in 143.599032 seconds
# Building cesm with output to /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/cesm.bldlog.230425-152015
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/cesm.exe -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/bld/cesm.exe.230425-152015
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_build.xml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles
# Time spent not building: 26.858212 sec
# Time spent building: 424.225639 sec
# MODEL BUILD HAS FINISHED SUCCESSFULLY

# %%
# !./xmlchange STOP_OPTION=nyears,STOP_N=1,REST_N=1,RESUBMIT=0,JOB_QUEUE=regular
# !./xmlchange JOB_WALLCLOCK_TIME=12:00:00

# %%
# !./case.submit
# Out:
# File /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles/env_batch.xml has been modified
#   found difference in USER_REQUESTED_WALLTIME : case '12:00:00' locked ''
#   found difference in USER_REQUESTED_QUEUE : case 'regular' locked ''
#
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
#
# Creating batch scripts
# Writing case.run script from input template /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_batch.xml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/env_batch.xml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/LockedFiles
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Creating component namelists
#   2023-04-25 15:28:07 atm
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cam//cime_config/buildnml
# CAM namelist copy: file1 /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/atm_in file2 /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_in
#   2023-04-25 15:28:07 lnd
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/clm//cime_config/buildnml
# WARNING: CLM is starting up from a cold state
#   2023-04-25 15:28:08 ice
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/cice//cime_config/buildnml
#   2023-04-25 15:28:08 ocn
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/pop//cime_config/buildnml
#      POP build-namelist: ocn_grid is gx1v7
# POP build-namelist: ocn_tracer_modules are iage wiso
#   2023-04-25 15:28:32 rof
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/components/rtm//cime_config/buildnml
#   2023-04-25 15:28:32 glc
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/sglc/cime_config/buildnml
#   2023-04-25 15:28:32 wav
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/swav/cime_config/buildnml
#   2023-04-25 15:28:32 esp
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/components/stub_comps/sesp/cime_config/buildnml
#   2023-04-25 15:28:32 cpl
#    Calling /glade/u/home/fengzhu/CESM/iCESM1.3_iHESP_hires_fzhu/cime/src/drivers/mct/cime_config/buildnml
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/drv_in -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs/drv_flds_in -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/seq_maps.rc -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/glc_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/ocn_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/esp_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/ice_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/wav_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/lnd_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/atm_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/rof_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/cplconf/cpl_modelio.nml -> /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run
# Finished creating component namelists
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/glc_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ocn_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/esp_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ice_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/wav_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/lnd_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/rof_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/cpl_modelio.nml -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/ice_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/rof_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/atm_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/drv_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/pop_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/drv_flds_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/lnd_in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/scratch/fengzhu/CESM_output/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/run/seq_maps.rc -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/chem_mech.in -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# copying /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/Buildconf/camconf/chem_mech.doc -> /glade/u/home/fengzhu/CESM/cases/b.e13.B1850C5.ne16_g17.icesm13_ihesp.PI.301/CaseDocs
# Checking that inputdata is available as part of case submission
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/clm.input_data_list'
# Model clm no file specified for finidat
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/pop.input_data_list'
# Loading input file list: 'Buildconf/cice.input_data_list'
# Loading input file list: 'Buildconf/mosart.input_data_list'
# Loading input file list: 'Buildconf/cam.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300324 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 9784248.chadmin1.ib0.cheyenne.ucar.edu
# Submit job case.st_archive
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300324  -W depend=afterok:9784248.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 9784249.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 9784248.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 9784249.chadmin1.ib0.cheyenne.ucar.edu

# %%
# !qstat -u fengzhu
