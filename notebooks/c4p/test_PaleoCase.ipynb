# %%
# %load_ext autoreload
# %autoreload 2

import c4p
print(c4p.__version__)
# Out:
# 0.0.2

# %%
case = c4p.PaleoCase(casename='Miocene', work_dirpath='/glade/u/home/fengzhu/CESM/test_c4p')
# Out:
# >>> /glade/u/home/fengzhu/CESM/test_c4p created
# >>> Current directory switched to: /glade/u/home/fengzhu/CESM/test_c4p

# %%
case.setup_rtm(
    topo_path='/glade/work/jiangzhu/data/inputdata/miocene/miocene_topo_pollard_antscape_dolan_0.5x0.5.nc',
    ocn_scrp_path='/glade/work/jiangzhu/data/inputdata/miocene/gx1vMIO_130423.nc',
    grids_dirpath='/glade/p/cesmdata/inputdata/share/scripgrids',
)
# Out:
# >>> Prep topo file at proper resolution ...
# CMD >>> svn export https://github.com/CESM-Development/paleoToolkit/trunk/cesm1_2/rof/create-topo_1x1deg.ncl create-topo_1x1deg.ncl
# A    create-topo_1x1deg.ncl
# Export complete.
# CMD >>> source /glade/u/apps/ch/opt/lmod/8.7.13/lmod/lmod/init/zsh && module load ncl && ncl create-topo_1x1deg.ncl
# >>> Generate runoff data from topo inputs ...
# CMD >>> svn export https://github.com/CESM-Development/paleoToolkit/trunk/cesm1_2/rof/rdirc_template.csh ./rdirc_Miocene.csh
# A    rdirc_Miocene.csh
# Export complete.
# CMD >>> svn export https://github.com/CESM-Development/paleoToolkit/trunk/cesm1_2/rof/topo2rdirc_sed.F90 topo2rdirc_sed.F90
# A    topo2rdirc_sed.F90
# Export complete.
# CMD >>> svn export https://github.com/CESM-Development/paleoToolkit/trunk/cesm1_2/rof/Makefile Makefile
# A    Makefile
# Export complete.
# CMD >>> chmod +x ./rdirc_Miocene.csh
# CMD >>> ././rdirc_Miocene.csh
# ...

# %%
# !tree '/glade/u/home/fengzhu/CESM/test_c4p'
# Out:
# /glade/u/home/fengzhu/CESM/test_c4p
# ├── create_ESMF_map.sh
# ├── create-topo_1x1deg.ncl
# ├── fort.10_Miocene
# ├── fort.11_Miocene
# ├── fort.12_Miocene
# ├── fort.13_Miocene
# ├── fort.14_Miocene
# ├── fort.15_Miocene
# ├── Makefile
# ├── map_r19_nomask_TO_r1x1_aave.230531.nc
# ├── map_r1_nomask_TO_gx1Miocene_aave.230531.nc
# ├── map_r1x1Miocene_to_gx1Miocene_nn_20230514.nc
# ├── map_r1x1Miocene_to_gx1Miocene_nnsm_e1000r300_20230514.nc
# ├── map_r1x1Miocene_to_gx1Miocene_sm_e1000r300_20230514.nc
# ├── map_r1x1_TO_r19_aave.230531.nc
# ├── pathname.sed
# ├── PET0.RegridWeightGen.Log
# ├── plotrdirc.csh
# ├── plot_rdirc.ncl
# ├── rdirc.1x1.Miocene
# ├── rdirc.1x1.Miocene.nc
# ├── rdirc_Miocene.csh
# ├── rdirc_miocene_topo_pollard_antscape_dolan_0.5x0.5.nc.png
# ├── rtm_ncdf.pro
# ├── runoff_map_1deg
# ├── runoff_map.1x1.Miocene.nml
# ├── runoff_map.nml -> ./runoff_map.1x1.Miocene.nml
# ├── topo.1x1deg.Miocene.nc
# ├── topo2rdirc
# ├── topo2rdirc.F90
# └── topo2rdirc_sed.F90
#
# ...
